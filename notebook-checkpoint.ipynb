# %%
#!pip install selenium
#!pip install pymongo

# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
import pymongo
from random import randint
from time import sleep
import re
import numpy as np
import matplotlib.pyplot as plt
from pylab import *

# %%
browser = webdriver.Chrome('C:/Users/Utilisateur/Documents/chromedriver_win32/chromedriver.exe')

# %%
browser.get('https://stockx.com/fr-fr/sneakers/most-popular?page=1')
sleep(randint(3,5))

# %%
browser.maximize_window()
sleep(randint(3,7))

# %%
cookies = browser.find_element_by_xpath('//*[@id="root"]/div[2]/div/div[2]/button')
cookies.click()
sleep(randint(3,4))

# %%
#Connexion bdd Mongo
try:
    bddMongo = pymongo.MongoClient("mongodb://localhost:27017/")

    mydb = bddMongo["stockx"]
    
    dblist = bddMongo.list_database_names()
    if "stockx" in dblist:
        print("The database exists.")
    
    mycol = mydb["meilleurs"]

    collist = mydb.list_collection_names()
    if "meilleurs" in collist:
        print("The collection exists.")

except pymongo.errors.ConnectionFailure :
    print("Could not connect to server")

# %%
def title():
    lstTitle = []
    title = browser.find_elements_by_class_name("css-nfm48z")
    for element in title:
        lstTitle.append(element.text)
    print(lstTitle)
    return lstTitle

# %%
def price():
    lstprice = []
    price = browser.find_elements_by_class_name("css-ghbupc")
    for element in price:
        euros = element.text.replace(" €", "")
        if euros.find(",") != -1:
            euros.replace(",","")
        lstprice.append(element.text.replace(" €", ""))
    print(lstprice)
    return lstprice

# %%
def sales():
    lstsales = []
    sales = browser.find_elements_by_class_name("css-2xg9fh")
    for element in sales:
        Meilleure = element.text.replace("- Des Ventes: ", "")
        lstsales.append(Meilleure)
        while 'Meilleure Demande' in lstsales:
            lstsales.remove('Meilleure Demande')
    for element in lstsales:
        element = int(element)
    print(lstsales)
    return lstsales

# %%
def saveData(lstTitle, lstprice, lstsales):
    count = 0
    while len(lstTitle) > count:
        print(count)
        dictionnaire = {}
        dictionnaire["title"] = lstTitle[count]
        dictionnaire["price"] = int(lstprice[count])
        dictionnaire["sales"] = int(lstsales[count])
        print(dictionnaire)
        x = mycol.insert_one(dictionnaire)
        count +=1
        print(x)

# %%
lstTitle = title()
lstprice = price()
lstsales = sales()
saveData(lstTitle, lstprice, lstsales)
# Out:
# ['Jordan 5 Retro White Stealth (2021)', 'adidas Yeezy 700 V3 Kyanite', 'Jordan 9 Retro Change The World (W)', 'Jordan 1 Retro High White University Blue Black', 'Nike Air Max 90 NRG Bacon (2021)', 'adidas Yeezy Foam RNNR Sand', 'Jordan 3 Retro Georgetown (2021)', 'adidas Yeezy Boost 350 V2 Ash Pearl', 'adidas Yeezy Foam RNNR MXT Moon Gray', 'Nike Dunk Low Retro White Black (2021)', 'Jordan 6 Retro Carmine (2021)', 'Nike Air Force 1 Low Supreme White', 'Jordan 12 Retro Arctic Punch (GS)', 'Jordan 1 Retro High Rust Shadow', 'Jordan 1 Mid Paint Drip (GS)', 'Jordan 1 Mid SE All-Star (2021) (GS)', "Nike Air Force 1 Low White '07", 'adidas Yeezy Boost 350 V2 Black Red (2017/2020)', 'Nike Air Structure OG White Neo Teal', 'Jordan 1 Low Purple Magenta (W)', 'adidas Yeezy Desert Boot Taupe Blue', 'Jordan 1 Retro High White University Blue Black (GS)', 'Nike Dunk Low Retro Hyper Cobalt (2021)', 'Jordan 11 Retro Jubilee 25th Anniversary', 'Nike Dunk Low Orange Pearl (W)', 'Nike Air Max 1 Clot Kiss of Death (2021)', 'Jordan 5 Retro White Stealth 2021 (GS)', 'Jordan 1 Mid Carbon Fiber All-Star (2021)', 'Nike Air Max Pre-Day Light Liquid Lime', 'Nike Dunk High Syracuse (2021)', 'Nike Air Force 1 Low Supreme Black', 'adidas Yeezy Boost 700 V2 Cream', 'Jordan 1 Retro High Silver Toe (W)', 'Jordan 4 Retro Fire Red (2020)', 'Jordan 4 Retro Taupe Haze', 'adidas Yeezy Boost 350 V2 Carbon', 'Jordan 6 Retro Carmine 2021 (GS)', 'Jordan 1 Retro High Dark Mocha', 'Jordan 1 Mid Banned (2020)', 'Jordan 1 Low Paint Drip (GS)']
# ['207', '208', '215', '258', '174', '238', '191', '216', '231', '220', '197', '133', '134', '188', '112', '133', '77', '347', '129', '135', '227', '298', '130', '207', '193', '152', '130', '128', '129', '166', '124', '283', '203', '231', '276', '229', '124', '309', '87', '143']
# ['1590', '1517', '1345', '1196', '1150', '1096', '1094', '918', '842', '774', '734', '703', '668', '653', '577', '568', '553', '507', '497', '444', '443', '442', '437', '429', '415', '401', '389', '383', '357', '356', '349', '348', '339', '322', '272', '266', '257', '253', '251', '247']
# 0
# {'title': 'Jordan 5 Retro White Stealth (2021)', 'price': 207, 'sales': 1590}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890240>
# 1
# {'title': 'adidas Yeezy 700 V3 Kyanite', 'price': 208, 'sales': 1517}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890640>
# 2
# {'title': 'Jordan 9 Retro Change The World (W)', 'price': 215, 'sales': 1345}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890240>
# 3
# {'title': 'Jordan 1 Retro High White University Blue Black', 'price': 258, 'sales': 1196}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890640>
# 4
# {'title': 'Nike Air Max 90 NRG Bacon (2021)', 'price': 174, 'sales': 1150}
# <pymongo.results.InsertOneResult object at 0x0000029E3A4D1280>
# 5
# {'title': 'adidas Yeezy Foam RNNR Sand', 'price': 238, 'sales': 1096}
# <pymongo.results.InsertOneResult object at 0x0000029E3B102EC0>
# 6
# {'title': 'Jordan 3 Retro Georgetown (2021)', 'price': 191, 'sales': 1094}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890AC0>
# 7
# {'title': 'adidas Yeezy Boost 350 V2 Ash Pearl', 'price': 216, 'sales': 918}
# <pymongo.results.InsertOneResult object at 0x0000029E3B1026C0>
# 8
# {'title': 'adidas Yeezy Foam RNNR MXT Moon Gray', 'price': 231, 'sales': 842}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890AC0>
# 9
# {'title': 'Nike Dunk Low Retro White Black (2021)', 'price': 220, 'sales': 774}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890D40>
# 10
# {'title': 'Jordan 6 Retro Carmine (2021)', 'price': 197, 'sales': 734}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890800>
# 11
# {'title': 'Nike Air Force 1 Low Supreme White', 'price': 133, 'sales': 703}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890D40>
# 12
# {'title': 'Jordan 12 Retro Arctic Punch (GS)', 'price': 134, 'sales': 668}
# <pymongo.results.InsertOneResult object at 0x0000029E3B887CC0>
# 13
# {'title': 'Jordan 1 Retro High Rust Shadow', 'price': 188, 'sales': 653}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890240>
# 14
# {'title': 'Jordan 1 Mid Paint Drip (GS)', 'price': 112, 'sales': 577}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890C00>
# 15
# {'title': 'Jordan 1 Mid SE All-Star (2021) (GS)', 'price': 133, 'sales': 568}
# <pymongo.results.InsertOneResult object at 0x0000029E3B8872C0>
# 16
# {'title': "Nike Air Force 1 Low White '07", 'price': 77, 'sales': 553}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88E980>
# 17
# {'title': 'adidas Yeezy Boost 350 V2 Black Red (2017/2020)', 'price': 347, 'sales': 507}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88E900>
# 18
# {'title': 'Nike Air Structure OG White Neo Teal', 'price': 129, 'sales': 497}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890280>
# 19
# {'title': 'Jordan 1 Low Purple Magenta (W)', 'price': 135, 'sales': 444}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88E900>
# 20
# {'title': 'adidas Yeezy Desert Boot Taupe Blue', 'price': 227, 'sales': 443}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882EC0>
# 21
# {'title': 'Jordan 1 Retro High White University Blue Black (GS)', 'price': 298, 'sales': 442}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0C0A00>
# 22
# {'title': 'Nike Dunk Low Retro Hyper Cobalt (2021)', 'price': 130, 'sales': 437}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890800>
# 23
# {'title': 'Jordan 11 Retro Jubilee 25th Anniversary', 'price': 207, 'sales': 429}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890240>
# 24
# {'title': 'Nike Dunk Low Orange Pearl (W)', 'price': 193, 'sales': 415}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890CC0>
# 25
# {'title': 'Nike Air Max 1 Clot Kiss of Death (2021)', 'price': 152, 'sales': 401}
# <pymongo.results.InsertOneResult object at 0x0000029E3B887DC0>
# 26
# {'title': 'Jordan 5 Retro White Stealth 2021 (GS)', 'price': 130, 'sales': 389}
# <pymongo.results.InsertOneResult object at 0x0000029E3B887CC0>
# 27
# {'title': 'Jordan 1 Mid Carbon Fiber All-Star (2021)', 'price': 128, 'sales': 383}
# <pymongo.results.InsertOneResult object at 0x0000029E3B8909C0>
# 28
# {'title': 'Nike Air Max Pre-Day Light Liquid Lime', 'price': 129, 'sales': 357}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890680>
# 29
# {'title': 'Nike Dunk High Syracuse (2021)', 'price': 166, 'sales': 356}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890FC0>
# 30
# {'title': 'Nike Air Force 1 Low Supreme Black', 'price': 124, 'sales': 349}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890680>
# 31
# {'title': 'adidas Yeezy Boost 700 V2 Cream', 'price': 283, 'sales': 348}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890E80>
# 32
# {'title': 'Jordan 1 Retro High Silver Toe (W)', 'price': 203, 'sales': 339}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876C40>
# 33
# {'title': 'Jordan 4 Retro Fire Red (2020)', 'price': 231, 'sales': 322}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890A00>
# 34
# {'title': 'Jordan 4 Retro Taupe Haze', 'price': 276, 'sales': 272}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882C00>
# 35
# {'title': 'adidas Yeezy Boost 350 V2 Carbon', 'price': 229, 'sales': 266}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890D80>
# 36
# {'title': 'Jordan 6 Retro Carmine 2021 (GS)', 'price': 124, 'sales': 257}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6EF900>
# 37
# {'title': 'Jordan 1 Retro High Dark Mocha', 'price': 309, 'sales': 253}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88E580>
# 38
# {'title': 'Jordan 1 Mid Banned (2020)', 'price': 87, 'sales': 251}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876C00>
# 39
# {'title': 'Jordan 1 Low Paint Drip (GS)', 'price': 143, 'sales': 247}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88E580>

# %%
url='https://stockx.com/fr-fr/sneakers/most-popular?page='
for i in range(2, 26):
    sleep(randint(3,7))
    browser.get(url+str(i))
    lstTitle = title()
    lstprice = price()
    lstsales = sales()
    saveData(lstTitle, lstprice, lstsales)
# Out:
# ['Nike Air Max 1 Evolution Of Icons', 'adidas Yeezy Boost 350 V2 Zyon', 'Nike Dunk Low White Black (2021) (W)', 'Jordan 1 Retro High University Blue (TD)', 'Nike Dunk High SE All-Star (2021)', 'Jordan 1 Mid Hyper Royal Tumbled Leather', 'adidas Yeezy Boost 350 V2 Ash Blue', 'Nike Dunk Low Retro Medium Grey Varsity Red UNLV (2021)', 'Jordan 1 Mid University Gold (GS)', 'Crocs Classic Clog Justin Bieber with drew house 2 Lavender', 'adidas Yeezy Boost 380 Covellite', 'Jordan 3 Retro Cool Grey (2021)', 'Nike Blazer Mid 77 Vintage White Black', 'Nike Dunk Low Retro White Black (GS)', 'Jordan 1 Mid Banned 2020 (GS)', 'Jordan 1 Mid Signal Blue', 'Nike Air Max 95 NRG LeBron Lakers', 'Jordan 9 Retro Dark Charcoal University Gold', 'Nike Dunk Low Coast (W)', 'Jordan 1 Low Light Smoke Grey', 'Nike Air Max Tailwind V Skepta', 'Jordan 1 Retro High White Black Volt University Gold', 'Nike Dunk High Syracuse (W) (2021)', 'adidas Yeezy Boost 350 V2 Zebra', 'Jordan 1 Mid Hyper Royal (GS)', 'Jordan 1 Retro High NC to Chi Leather (W)', 'adidas Yeezy 450 Cloud White', 'Nike Air Force 1 Low Rose White', 'Jordan 1 Retro High OG University Blue (PS)', 'Jordan 3 Retro Georgetown 2021 (GS)', 'adidas Yeezy Boost 350 V2 Sand Taupe', 'Jordan 5 Retro White Stealth 2021 (TD)', 'Jordan 1 Retro High Lucky Green (W)', 'Jordan 1 Zoom Air CMFT PSG Paris Saint-Germain', 'Jordan 1 Retro High Black Metallic Gold (2020)', 'Nike Air Max 90 Infrared (2020)', 'adidas Yeezy Boost 350 V2 Ash Stone', 'Nike Kobe 6 Protro Challenge Red', 'Nike Dunk High Sail Football Grey (W)', 'Jordan 1 Mid Black Chile Red White']
# ['171', '213', '221', '91', '131', '101', '230', '167', '93', '73', '175', '179', '85', '225', '84', '123', '182', '207', '289', '119', '181', '166', '150', '325', '83', '164', '357', '114', '93', '117', '209', '85', '225', '191', '167', '99', '247', '170', '162', '119']
# ['247', '242', '239', '230', '227', '223', '222', '221', '220', '212', '212', '199', '198', '196', '195', '194', '191', '190', '187', '184', '183', '182', '177', '176', '172', '172', '172', '169', '168', '168', '166', '162', '162', '161', '160', '158', '156', '155', '153', '149']
# 0
# {'title': 'Nike Air Max 1 Evolution Of Icons', 'price': 171, 'sales': 247}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0D44C0>
# 1
# {'title': 'adidas Yeezy Boost 350 V2 Zyon', 'price': 213, 'sales': 242}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0C6840>
# 2
# {'title': 'Nike Dunk Low White Black (2021) (W)', 'price': 221, 'sales': 239}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0D44C0>
# 3
# {'title': 'Jordan 1 Retro High University Blue (TD)', 'price': 91, 'sales': 230}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882580>
# 4
# {'title': 'Nike Dunk High SE All-Star (2021)', 'price': 131, 'sales': 227}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882140>
# 5
# {'title': 'Jordan 1 Mid Hyper Royal Tumbled Leather', 'price': 101, 'sales': 223}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88A9C0>
# 6
# {'title': 'adidas Yeezy Boost 350 V2 Ash Blue', 'price': 230, 'sales': 222}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6E5800>
# 7
# {'title': 'Nike Dunk Low Retro Medium Grey Varsity Red UNLV (2021)', 'price': 167, 'sales': 221}
# <pymongo.results.InsertOneResult object at 0x0000029E3B852EC0>
# 8
# {'title': 'Jordan 1 Mid University Gold (GS)', 'price': 93, 'sales': 220}
# <pymongo.results.InsertOneResult object at 0x0000029E3B852FC0>
# 9
# {'title': 'Crocs Classic Clog Justin Bieber with drew house 2 Lavender', 'price': 73, 'sales': 212}
# <pymongo.results.InsertOneResult object at 0x0000029E3B852EC0>
# 10
# {'title': 'adidas Yeezy Boost 380 Covellite', 'price': 175, 'sales': 212}
# <pymongo.results.InsertOneResult object at 0x0000029E3B102540>
# 11
# {'title': 'Jordan 3 Retro Cool Grey (2021)', 'price': 179, 'sales': 199}
# <pymongo.results.InsertOneResult object at 0x0000029E3B852EC0>
# 12
# {'title': 'Nike Blazer Mid 77 Vintage White Black', 'price': 85, 'sales': 198}
# <pymongo.results.InsertOneResult object at 0x0000029E3B102840>
# 13
# {'title': 'Nike Dunk Low Retro White Black (GS)', 'price': 225, 'sales': 196}
# <pymongo.results.InsertOneResult object at 0x0000029E3B852EC0>
# 14
# {'title': 'Jordan 1 Mid Banned 2020 (GS)', 'price': 84, 'sales': 195}
# <pymongo.results.InsertOneResult object at 0x0000029E3B000540>
# 15
# {'title': 'Jordan 1 Mid Signal Blue', 'price': 123, 'sales': 194}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876280>
# 16
# {'title': 'Nike Air Max 95 NRG LeBron Lakers', 'price': 182, 'sales': 191}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88AB40>
# 17
# {'title': 'Jordan 9 Retro Dark Charcoal University Gold', 'price': 207, 'sales': 190}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882140>
# 18
# {'title': 'Nike Dunk Low Coast (W)', 'price': 289, 'sales': 187}
# <pymongo.results.InsertOneResult object at 0x0000029E3B8824C0>
# 19
# {'title': 'Jordan 1 Low Light Smoke Grey', 'price': 119, 'sales': 184}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882340>
# 20
# {'title': 'Nike Air Max Tailwind V Skepta', 'price': 181, 'sales': 183}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890280>
# 21
# {'title': 'Jordan 1 Retro High White Black Volt University Gold', 'price': 166, 'sales': 182}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890080>
# 22
# {'title': 'Nike Dunk High Syracuse (W) (2021)', 'price': 150, 'sales': 177}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882580>
# 23
# {'title': 'adidas Yeezy Boost 350 V2 Zebra', 'price': 325, 'sales': 176}
# <pymongo.results.InsertOneResult object at 0x0000029E3B887C40>
# 24
# {'title': 'Jordan 1 Mid Hyper Royal (GS)', 'price': 83, 'sales': 172}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0C0200>
# 25
# {'title': 'Jordan 1 Retro High NC to Chi Leather (W)', 'price': 164, 'sales': 172}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88AF80>
# 26
# {'title': 'adidas Yeezy 450 Cloud White', 'price': 357, 'sales': 172}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876CC0>
# 27
# {'title': 'Nike Air Force 1 Low Rose White', 'price': 114, 'sales': 169}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88EA00>
# 28
# {'title': 'Jordan 1 Retro High OG University Blue (PS)', 'price': 93, 'sales': 168}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876CC0>
# 29
# {'title': 'Jordan 3 Retro Georgetown 2021 (GS)', 'price': 117, 'sales': 168}
# <pymongo.results.InsertOneResult object at 0x0000029E3B706DC0>
# 30
# {'title': 'adidas Yeezy Boost 350 V2 Sand Taupe', 'price': 209, 'sales': 166}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882340>
# 31
# {'title': 'Jordan 5 Retro White Stealth 2021 (TD)', 'price': 85, 'sales': 162}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876C00>
# 32
# {'title': 'Jordan 1 Retro High Lucky Green (W)', 'price': 225, 'sales': 162}
# <pymongo.results.InsertOneResult object at 0x0000029E3B8824C0>
# 33
# {'title': 'Jordan 1 Zoom Air CMFT PSG Paris Saint-Germain', 'price': 191, 'sales': 161}
# <pymongo.results.InsertOneResult object at 0x0000029E3B000540>
# 34
# {'title': 'Jordan 1 Retro High Black Metallic Gold (2020)', 'price': 167, 'sales': 160}
# <pymongo.results.InsertOneResult object at 0x0000029E3B887C40>
# 35
# {'title': 'Nike Air Max 90 Infrared (2020)', 'price': 99, 'sales': 158}
# <pymongo.results.InsertOneResult object at 0x0000029E3B706BC0>
# 36
# {'title': 'adidas Yeezy Boost 350 V2 Ash Stone', 'price': 247, 'sales': 156}
# <pymongo.results.InsertOneResult object at 0x0000029E3B706080>
# 37
# {'title': 'Nike Kobe 6 Protro Challenge Red', 'price': 170, 'sales': 155}
# <pymongo.results.InsertOneResult object at 0x0000029E3B712AC0>
# 38
# {'title': 'Nike Dunk High Sail Football Grey (W)', 'price': 162, 'sales': 153}
# <pymongo.results.InsertOneResult object at 0x0000029E3B8870C0>
# 39
# {'title': 'Jordan 1 Mid Black Chile Red White', 'price': 119, 'sales': 149}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88E900>
# ['Nike Dunk High Retro White Vast Grey (2021)', 'adidas Yeezy 700 V3 Arzareth', 'adidas Yeezy 700 V3 Clay Brown', 'adidas Yeezy 500 Utility Black', 'Nike Dunk Low Medium Curry', 'Nike Air More Uptempo Rayguns', 'Jordan 5 Retro What The', 'Jordan 1 Mid Triple White 2.0 (2020)', 'Jordan 4 Retro Taupe Haze (GS)', 'Jordan 5 Retro Anthracite', 'Jordan 12 Retro Arctic Punch (TD)', 'Nike SB Dunk Low Wasted Youth', 'Jordan 9 Retro Dark Charcoal University Gold (GS)', 'adidas NMD Hu Pharrell Pink', 'Jordan 11 Retro Jubilee (GS)', 'Nike Air VaporMax Plus Triple Black', 'Jordan 12 Retro Reverse Flu Game', 'Nike Dunk Low College Navy Grey (W)', 'Nike Dunk High SP Syracuse (GS) (2021)', 'Nike Air Max 95 NYC Taxi', 'Jordan 13 Retro Black Hyper Royal', 'Nike SB Dunk Low Club 58 Gulf', 'Jordan 1 Low SE All-Star (2021)', 'adidas Yeezy Boost 350 V2 Israfil', 'Jordan 1 Mid Apricot Orange (W)', 'Jordan 1 Low Reverse Bred', 'Jordan 1 Low Court Purple White', 'adidas Yeezy Boost 350 V2 Desert Sage', 'Nike Air Max 97 Swarovski Polar Blue (W)', 'Nike Air Force 1 Low White Gum', 'Nike Air Max 95 OG Neon (2020)', 'Nike Dunk Low Retro Medium Grey Varsity Red UNLV (GS) (2021)', 'Nike Air Max Plus City Special ATL (W)', 'Jordan 5 Retro Alternate Bel-Air', 'Jordan 1 Retro High Pine Green Black', 'Jordan 1 Mid Chicago Toe', 'Nike Air Vapormax EVO NRG Air Max Day Mashup (2021)', 'Reebok Pump Omni Zone II Dee Brown (2021', 'Jordan 1 Retro High Light Smoke Grey', 'Jordan 1 Mid Canyon Rust (W)']
# ['158', '289', '209', '281', '319', '148', '182', '110', '187', '221', '59', '486', '137', '203', '141', '162', '181', '178', '131', '145', '213', '234', '101', '229', '168', '88', '88', '220', '446', '95', '195', '141', '172', '179', '183', '167', '197', '131', '197', '126']
# ['149', '149', '146', '145', '145', '144', '144', '141', '139', '139', '138', '138', '137', '135', '133', '133', '133', '132', '131', '131', '131', '131', '130', '130', '129', '128', '124', '123', '123', '121', '119', '117', '117', '116', '115', '114', '114', '113', '111', '110']
# 0
# {'title': 'Nike Dunk High Retro White Vast Grey (2021)', 'price': 158, 'sales': 149}
# <pymongo.results.InsertOneResult object at 0x0000029E3B706A00>
# 1
# {'title': 'adidas Yeezy 700 V3 Arzareth', 'price': 289, 'sales': 149}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876940>
# 2
# {'title': 'adidas Yeezy 700 V3 Clay Brown', 'price': 209, 'sales': 146}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876200>
# 3
# {'title': 'adidas Yeezy 500 Utility Black', 'price': 281, 'sales': 145}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876940>
# 4
# {'title': 'Nike Dunk Low Medium Curry', 'price': 319, 'sales': 145}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876400>
# 5
# {'title': 'Nike Air More Uptempo Rayguns', 'price': 148, 'sales': 144}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0CBFC0>
# 6
# {'title': 'Jordan 5 Retro What The', 'price': 182, 'sales': 144}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876940>
# 7
# {'title': 'Jordan 1 Mid Triple White 2.0 (2020)', 'price': 110, 'sales': 141}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876EC0>
# 8
# {'title': 'Jordan 4 Retro Taupe Haze (GS)', 'price': 187, 'sales': 139}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6E5F40>
# 9
# {'title': 'Jordan 5 Retro Anthracite', 'price': 221, 'sales': 139}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882F00>
# 10
# {'title': 'Jordan 12 Retro Arctic Punch (TD)', 'price': 59, 'sales': 138}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876140>
# 11
# {'title': 'Nike SB Dunk Low Wasted Youth', 'price': 486, 'sales': 138}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876200>
# 12
# {'title': 'Jordan 9 Retro Dark Charcoal University Gold (GS)', 'price': 137, 'sales': 137}
# <pymongo.results.InsertOneResult object at 0x0000029E3B706C40>
# 13
# {'title': 'adidas NMD Hu Pharrell Pink', 'price': 203, 'sales': 135}
# <pymongo.results.InsertOneResult object at 0x0000029E3B890580>
# 14
# {'title': 'Jordan 11 Retro Jubilee (GS)', 'price': 141, 'sales': 133}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6E5E40>
# 15
# {'title': 'Nike Air VaporMax Plus Triple Black', 'price': 162, 'sales': 133}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6E56C0>
# 16
# {'title': 'Jordan 12 Retro Reverse Flu Game', 'price': 181, 'sales': 133}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0CBFC0>
# 17
# {'title': 'Nike Dunk Low College Navy Grey (W)', 'price': 178, 'sales': 132}
# <pymongo.results.InsertOneResult object at 0x0000029E3B882C80>
# 18
# {'title': 'Nike Dunk High SP Syracuse (GS) (2021)', 'price': 131, 'sales': 131}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6F7580>
# 19
# {'title': 'Nike Air Max 95 NYC Taxi', 'price': 145, 'sales': 131}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0F4440>
# 20
# {'title': 'Jordan 13 Retro Black Hyper Royal', 'price': 213, 'sales': 131}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6F7B40>
# 21
# {'title': 'Nike SB Dunk Low Club 58 Gulf', 'price': 234, 'sales': 131}
# <pymongo.results.InsertOneResult object at 0x0000029E3B71F0C0>
# 22
# {'title': 'Jordan 1 Low SE All-Star (2021)', 'price': 101, 'sales': 130}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6F7F80>
# 23
# {'title': 'adidas Yeezy Boost 350 V2 Israfil', 'price': 229, 'sales': 130}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876680>
# 24
# {'title': 'Jordan 1 Mid Apricot Orange (W)', 'price': 168, 'sales': 129}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6F7A00>
# 25
# {'title': 'Jordan 1 Low Reverse Bred', 'price': 88, 'sales': 128}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6E56C0>
# 26
# {'title': 'Jordan 1 Low Court Purple White', 'price': 88, 'sales': 124}
# <pymongo.results.InsertOneResult object at 0x0000029E3B876500>
# 27
# {'title': 'adidas Yeezy Boost 350 V2 Desert Sage', 'price': 220, 'sales': 123}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88E840>
# 28
# {'title': 'Nike Air Max 97 Swarovski Polar Blue (W)', 'price': 446, 'sales': 123}
# <pymongo.results.InsertOneResult object at 0x0000029E3B0CBFC0>
# 29
# {'title': 'Nike Air Force 1 Low White Gum', 'price': 95, 'sales': 121}
# <pymongo.results.InsertOneResult object at 0x0000029E3B8822C0>
# 30
# {'title': 'Nike Air Max 95 OG Neon (2020)', 'price': 195, 'sales': 119}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6F7B40>
# 31
# {'title': 'Nike Dunk Low Retro Medium Grey Varsity Red UNLV (GS) (2021)', 'price': 141, 'sales': 117}
# <pymongo.results.InsertOneResult object at 0x0000029E3B852B80>
# 32
# {'title': 'Nike Air Max Plus City Special ATL (W)', 'price': 172, 'sales': 117}
# <pymongo.results.InsertOneResult object at 0x0000029E3B8822C0>
# 33
# {'title': 'Jordan 5 Retro Alternate Bel-Air', 'price': 179, 'sales': 116}
# <pymongo.results.InsertOneResult object at 0x0000029E3B709540>
# 34
# {'title': 'Jordan 1 Retro High Pine Green Black', 'price': 183, 'sales': 115}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6F7F80>
# 35
# {'title': 'Jordan 1 Mid Chicago Toe', 'price': 167, 'sales': 114}
# <pymongo.results.InsertOneResult object at 0x0000029E3B706B00>
# 36
# {'title': 'Nike Air Vapormax EVO NRG Air Max Day Mashup (2021)', 'price': 197, 'sales': 114}
# <pymongo.results.InsertOneResult object at 0x0000029E3B6E5400>
# 37
# {'title': 'Reebok Pump Omni Zone II Dee Brown (2021', 'price': 131, 'sales': 113}
# <pymongo.results.InsertOneResult object at 0x0000029E3B712200>
# 38
# {'title': 'Jordan 1 Retro High Light Smoke Grey', 'price': 197, 'sales': 111}
# <pymongo.results.InsertOneResult object at 0x0000029E3B709680>
# 39
# {'title': 'Jordan 1 Mid Canyon Rust (W)', 'price': 126, 'sales': 110}
# <pymongo.results.InsertOneResult object at 0x0000029E3B88E5C0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-0e0710697cfc> in <module>
#       1 url='https://stockx.com/fr-fr/sneakers/most-popular?page='
#       2 for i in range(2, 26):
# ----> 3     sleep(randint(3,7))
#       4     browser.get(url+str(i))
#       5     lstTitle = title()
#
# KeyboardInterrupt:

# %%
# prix suppérieur à 1000€

result = mycol.find({"price": {"$gte": 1000}})

tabprice = []
tabnbvaleur = []
count = 1

for i in result:
    tabprice.append(i["price"])
    tabnbvaleur.append(count)
    print(str(count) + " : " + i["title"] + " avec " + str(i["price"]) + " €")
    count += 1


plot(tabnbvaleur, tabprice)
show()

# %%
# result = mycol.aggregate(
#    [{ "_id": '$id',
#    "$group":
#        {"price": {"$gte": "$price"}
#        }}
#    ])

# %%
# ventes total

result = mycol.find()
totalVente = 0
totalPrix = 0

for i in result:
    totalPrix = totalPrix + (i["sales"] * i["price"])
    totalVente = totalVente + i["sales"]
    
print("Si les tous les exemplaires des 1000 chaussures sont vendu (" + str(totalVente) + ") cela représente un CA de " + str(totalPrix) + " €.")
# Out:
# Si les tous les exemplaires des 1000 chaussures sont vendu (37130) cela représente un CA de 6940523 €.

# %%
# result = mycol.aggregate(
#    [{ "_id": '$id',
#    "$group":
#        {"price": {"$sum": "$sales"}
#        }}
#    ])

# for i in result:
#    print(i)
